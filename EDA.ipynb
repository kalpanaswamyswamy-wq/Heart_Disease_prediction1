# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from seaborn) (3.0.3)
# Collecting matplotlib!=3.6.1,>=3.4
#   Downloading matplotlib-3.11.1-cp311-cp311-win_amd64.whl (9.3 MB)
#      ---------------------------------------- 9.3/9.3 MB 1.3 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.28.2
#   Using cached fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Collecting pyparsing>=3
#   Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pyparsing-3.3.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (2.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as numpy
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv("heart.csv")

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
#renaming the column
d={'cp':'chest_pain_type',
   'trestbps':'resting_bp',
   'chol':'cholestoral',
   'fbs':'fasting_blood_sugar',
   'thalach':'maximum_heart_rate',
   'exang':'exercise_induced_angina',
   'ca':'number of major vessels'
   }
df.rename(columns=d,inplace=True)
df.head()
# Out:
#    age  sex  chest_pain_type  resting_bp  cholestoral  fasting_blood_sugar  \
# 0   63    1                3         145          233                    1
# 1   37    1                2         130          250                    0
# 2   41    0                1         130          204                    0
# 3   56    1                1         120          236                    0
# 4   57    0                0         120          354                    0
#
#    restecg  maximum_heart_rate  exercise_induced_angina  oldpeak  slope  \
# 0        0                 150                        0      2.3      0
# 1        1                 187                        0      3.5      0
# 2        0                 172                        0      1.4      2
# 3        1                 178                        0      0.8      2
# 4        1                 163                        1      0.6      2
#
#    number of major vessels  thal  target
# 0                        0     1       1
# 1                        0     2       1
# 2                        0     2       1
# 3                        0     2       1
# 4                        0     2       1

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sns.countplot(x="target",data=df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\kalpa\onedrive\attachments\desktop\heart_disease_prediction\myenv\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC 
from sklearn.ensemble import RandomForestClassifier

# %%
x=df.drop("target",axis=1)
y=df.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=[LogisticRegression(),SVC(kernel="linear"),
       RandomForestClassifier(n_estimators=100,max_depth=5)]
for m in model:
    model=m
    model=model.fit(x_train,y_train)
    print("MODEL:",m)
    print("training efficiency:",model.score(x_train,y_train))
    print("training efficiency:",model.score(x_train,y_train))
# Out:
# c:\Users\kalpa\OneDrive\Attachments\Desktop\Heart_Disease_Prediction\myenv\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# MODEL: LogisticRegression()
# training efficiency: 0.8679245283018868
# training efficiency: 0.8679245283018868
# MODEL: SVC(kernel='linear')
# training efficiency: 0.8820754716981132
# training efficiency: 0.8820754716981132
# MODEL: RandomForestClassifier(max_depth=5)
# training efficiency: 0.9716981132075472
# training efficiency: 0.9716981132075472

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# c:\Users\kalpa\OneDrive\Attachments\Desktop\Heart_Disease_Prediction\myenv\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Training effiency:",model.score(x_train,y_train))
print("Training effiency:",model.score(x_test,y_test))
# Out:
# Training effiency: 0.8679245283018868
# Training effiency: 0.8131868131868132

# %%
y_pred=model.predict(x_test)

# %%
print("ACCURACY  :",accuracy_score(y_test,y_pred))
print("RECALL :",recall_score(y_test,y_pred))
# Out:
# ACCURACY  : 0.8131868131868132
# RECALL : 0.84

# %%
df.to_csv("cleaned_data.csv")

# %%
import joblib
with open("Log_model.joblib","wb") as file:
    joblib.dump(model,file)
